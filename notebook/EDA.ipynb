# %%
import pandas as pd
import plotly.express as px

# --- Step 2: Load the dataset ---
df = pd.read_csv('../vehicles_us.csv')  # adjust the path if needed
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
# --- Step 3: Basic overview ---
df.info()
df.describe()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %%
# --- Step 4: Clean a bit (optional) ---
# Fill missing values or drop duplicates if needed
df = df.drop_duplicates()
df['model_year'] = df['model_year'].fillna(df['model_year'].median())
df['odometer'] = df['odometer'].fillna(df['odometer'].median())

# %%
# !pip install nbformat
# Out:
# Requirement already satisfied: nbformat in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.4.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)

# %%
# !pip install nbformat
# Out:
# Collecting nbformat
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting fastjsonschema>=2.15 (from nbformat)
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jsonschema>=2.6 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.4.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /Users/thewellnessnetwork/triple_ten_app/.venv/lib/python3.9/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Installing collected packages: fastjsonschema, nbformat
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nbformat]
# Successfully installed fastjsonschema-2.21.2 nbformat-5.10.4

# %%
import nbformat
print(nbformat.__version__)
# Out:
# 5.10.4

# %%
fig_price = px.histogram(df, x='price', nbins=50, title='Distribution of Car Prices')
fig_price.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fig_price = px.histogram(df, x='price', nbins=50, title='Distribution of Car Prices')
#       2 fig_price.show()
#
# NameError: name 'px' is not defined

# %%
fig_price = px.histogram(df, x='price', nbins=50, title='Distribution of Car Prices')
fig_price.show()

# %%
# --- Step 6: Create scatter plots ---
fig_scatter_price_odometer = px.scatter(
    df, 
    x='odometer', 
    y='price', 
    color='type',
    title='Price vs Odometer (by Car Type)'
)
fig_scatter_price_odometer.show()

fig_year_price = px.scatter(
    df, 
    x='model_year', 
    y='price', 
    color='fuel',
    title='Car Price vs Model Year (by Fuel Type)'
)
fig_year_price.show()

# %%
# --- Step 7: Creative insight examples ---
# Average price by manufacturer
avg_price_by_make = df.groupby('model')['price'].mean().reset_index()
fig_make_price = px.bar(
    avg_price_by_make.sort_values('price', ascending=False).head(20),
    x='model',
    y='price',
    title='Top 20 Models by Average Price'
)
fig_make_price.show()

# %%
# --- Step 8: Summary ---
print("EDA complete — histograms and scatter plots created successfully!")
# Out:
# EDA complete — histograms and scatter plots created successfully!

# %%
## Scatter Plots

The following scatter plots show how key factors relate to car price. 
The first explores the relationship between mileage and price, colored by condition, 
while the second examines how car age (model year) and transmission type influence price distribution.

# %%
fig_scatter_odometer = px.scatter(
    df,
    x='odometer',
    y='price',
    color='condition',
    title='Price vs Odometer (by Condition)',
    labels={'odometer': 'Mileage (Odometer)', 'price': 'Price ($)'},
    opacity=0.6
)
fig_scatter_odometer.show()

# %%
fig_scatter_year = px.scatter(
    df,
    x='model_year',
    y='price',
    color='transmission',
    title='Model Year vs Price (by Transmission Type)',
    labels={'model_year': 'Model Year', 'price': 'Price ($)'},
    opacity=0.7
)
fig_scatter_year.show()
